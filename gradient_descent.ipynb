# %%
from gradient_descent import Ridge_Regression, Gradient_Descent, calc_mse, test_implementations, print_val
import numpy as np

# %%
X_train = np.loadtxt(open("datasets/housing_X_train.csv", "rb"), delimiter=",")
y_train = np.loadtxt(open("datasets/housing_y_train.csv", "rb"), delimiter=",")
X_test = np.loadtxt(open("datasets/housing_X_test.csv", "rb"), delimiter=",")
y_test = np.loadtxt(open("datasets/housing_y_test.csv", "rb"), delimiter=",")
# standardized data for gradient descent
X_train_std = ((X_train-np.mean(X_train, axis=0))/np.std(X_train, axis=0)).T
X_test_std = ((X_test-np.mean(X_test, axis=0))/np.std(X_test, axis=0)).T
X_train = np.vstack((X_train, [1]*len(X_train[0]))).T
X_test = np.vstack((X_test, [1]*len(X_test[0]))).T

# %%
test_implementations(X_train, y_train, X_test, y_test, X_train_std, X_test_std)
# Out:
# Lambda: 0
# --Ridge Regression--
# Running time:  0.0003752999999999673
# Training error: 9.694298638909318
# Test error: 370.2229572985301
# --Gradient Descent--
# Running time:  0.11534909999999954
# Training error: 574.84214096271
# Test error: 282.32742955844304
# ...
