# %%
import numpy as np
from regressions import run_model, plot_data, split_dataset, calc_mse

# %%
# load data
X_test_A = np.loadtxt(open("datasets/X_test_A.csv", "rb"), delimiter=",")
X_test_B = np.loadtxt(open("datasets/X_test_B.csv", "rb"), delimiter=",")
X_test_C = np.loadtxt(open("datasets/X_test_C.csv", "rb"), delimiter=",")
X_train_A = np.loadtxt(open("datasets/X_train_A.csv", "rb"), delimiter=",")
X_train_B = np.loadtxt(open("datasets/X_train_B.csv", "rb"), delimiter=",")
X_train_C = np.loadtxt(open("datasets/X_train_C.csv", "rb"), delimiter=",")
Y_test_A = np.loadtxt(open("datasets/Y_test_A.csv", "rb"), delimiter=",")
Y_test_B = np.loadtxt(open("datasets/Y_test_B.csv", "rb"), delimiter=",")
Y_test_C = np.loadtxt(open("datasets/Y_test_C.csv", "rb"), delimiter=",")
Y_train_A = np.loadtxt(open("datasets/Y_train_A.csv", "rb"), delimiter=",")
Y_train_B = np.loadtxt(open("datasets/Y_train_B.csv", "rb"), delimiter=",")
Y_train_C = np.loadtxt(open("datasets/Y_train_C.csv", "rb"), delimiter=",")

# %% [markdown]
# This creates a histogram where the x-axis is divided into bins corresponding to the values of coordinates of the parameter vector, and the y-axis is the number of coordinates of the parameter vector which fall into each bin. For ridge and lasso regression, the hyperparameter that minimizes the loss is chosen. Average mean squared error for each model is also found.

# %%
run_model(X_test_A,X_train_A,Y_test_A,Y_train_A)
run_model(X_test_B,X_train_B,Y_test_B,Y_train_B)
run_model(X_test_C,X_train_C,Y_test_C,Y_train_C)
# Out:
# ridge hyperparameter:  9.7
# lasso hyperparameter:  0.01
# Average mean squared error of each model:
# Unregularized linear model:  3.2474001735563265
# Ridge regression model:  2.7800978559325324
# Lasso regression model:  2.815554592396192
# ridge hyperparameter:  54.9
# lasso hyperparameter:  0.03
# Average mean squared error of each model:
# Unregularized linear model:  2.742682374651706
# Ridge regression model:  1.794458909668764
# Lasso regression model:  1.7907475049857615
# ridge hyperparameter:  0.1
# lasso hyperparameter:  0.14
# Average mean squared error of each model:
# Unregularized linear model:  506.1084477369717
# Ridge regression model:  506.24141706882205
# Lasso regression model:  1.2406033474703484
